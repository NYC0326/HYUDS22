# %% [markdown]
# # Calculation

# %% [markdown]
# ### Case 1

# %%
print(4 * 5)
print(10 % 2)
print(10 % 3)
try:
    print(4 / 0)
except ZeroDivisionError as e:
    print(e)
# Out:
# 20
# 0
# 1
# division by zero

# %% [markdown]
# ### Case 2

# %%
(10+1) * 3 / 2
min(5, 10, 25)
max(5, 10, 25)
abs(-7.25)
# Out:
# 7.25

# %% [markdown]
# # Print

# %% [markdown]
# ### Case 1

# %%
print('Hello, World!')
print('Hello,' + 'World!')
print('Hello,', 'World!')
# Out:
# Hello, World!
# Hello,World!
# Hello, World!

# %%
print(2 + 4)
print('2'+ '4')
print(2, 4)
print('2', '4')
# Out:
# 6
# 24
# 2 4
# 2 4

# %% [markdown]
# ### Case 2

# %%
print('Hello, World!')
print('Hello,' + 'World!')
print(pow(4, 3))
# Out:
# Hello, World!
# Hello,World!
# 64

# %% [markdown]
# ### Case 3

# %%
#This is a comment
print('Hello, World!')

#Hello, World!
# Out:
# Hello, World!

# %% [markdown]
# # Variable

# %% [markdown]
# ### Case 1

# %%
x = 5
y = 'Sam'

print(x)
print(y)

z = 'easy'
print('Python is ' + z)
# Out:
# 5
# Sam
# Python is easy

# %% [markdown]
# ### Case 2

# %%
x = 'Python is '
y = 'awesome'
z =  x + y
print(z)

x = 5
y = 10
print(x + y)
# Out:
# Python is awesome
# 15

# %% [markdown]
# ### Case 3

# %%
x = 'Sam ' * 5

print(x)

y = 'James' + 2 
z = 'James' – 2
w = 'James' / 1
# Out:
#   File "C:\Users\남유찬\AppData\Local\Temp/ipykernel_8348/3287824919.py", line 6
#     z = 'James' – 2
#                 ^
# SyntaxError: invalid character '–' (U+2013)

# %% [markdown]
# # Casting

# %% [markdown]
# ### Case 1

# %%
x = str(3)    # x is '3'
y = int(3)    # y is 3
z = float(3)  # z is 3.0

# %% [markdown]
# ### Case 2

# %%
x = str(3)
print(x + x)
x = int(3)
print(x + x)
# Out:
# 33
# 6

# %% [markdown]
# # Variable Name

# %% [markdown]
# ### Case 1

# %%
myvar = 'Sam'
my_var = 'Sam'
_my_var = 'Sam'
myVar = 'Sam'
MYVAR = 'Sam'
myvar2 = 'Sam'

# %% [markdown]
# ### Case 2

# %%
2myvar = "John"
my-var = "John"
my var = "John"
# Out:
#   File "C:\Users\남유찬\AppData\Local\Temp/ipykernel_8348/2185399839.py", line 1
#     2myvar = "John"
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Multiple variable

# %% [markdown]
# ### Case 1

# %%
x = y = z = 'ABC'
print(x)
print(y)
print(z)
# Out:
# ABC
# ABC
# ABC

# %% [markdown]
# ### Quiz 1-1

# %%
print('2022084520', 'Yuchan Nam')
# Out:
# 2022084520 Yuchan Nam

# %% [markdown]
# ### Quiz 1-2

# %%
a = 10
b = 'hello'
c = 3.1

print(a)
print(b)
print(c)
# Out:
# 10
# hello
# 3.1

# %% [markdown]
# ### Quiz 1-3

# %%
a = 10
b = 'hello'
c = 3.1

print(str(a) + b + str(c))
# Out:
# 10hello3.1

# %% [markdown]
# # Print 2

# %% [markdown]
# ### Case 1

# %%
print('A' + 'B' + 'C')
print('A', 'B', 'C')
print('A', 'B', 'C', sep='')
print('1', '2', '3', sep='+')
# Out:
# ABC
# A B C
# ABC
# 1+2+3

# %% [markdown]
# ### Case 2

# %%
print('I want to go ')
print('home')
print('I want to go ', end='')
print('home')
print('I want to go ', end='home')
# Out:
# I want to go
# home
# I want to go home
# I want to go home

# %% [markdown]
# ### Case 3

# %%
print('Alice : What would you like to have for lunch?')
print('Bob : Hamburger.')

print('Alice : What would you like to have for lunch?\nBob : Hamburger')
# Out:
# Alice : What would you like to have for lunch?
# Bob : Hamburger.
# Alice : What would you like to have for lunch?
# Bob : Hamburger

# %% [markdown]
# ### Case 4

# %%
print('*            *')

print('*\t*')
# Out:
# *            *
# *	*

# %% [markdown]
# ### Case 5

# %%
print('name\tphone number\taddress\tsocial security number')
print('Mathew\t010-0000-0000\tSeoul\t00000-0000000')
# Out:
# name	phone number	address	social security number
# Mathew	010-0000-0000	Seoul	00000-0000000

# %% [markdown]
# ### Case 6

# %%
print('I want to print a double quote "')
# print("I want to print a double quote "") #error
print("I want to print a double quote \"")
# Out:
# I want to print a double quote "
# I want to print a double quote "

# %% [markdown]
# ### Case 7

# %%
str1 = """Python is a high-level and general-purpose programming language.
Python's design philosophy emphasizes code readability 
with its notable use of significant indentation.
"""

print(str1)
# Out:
# Python is a high-level and general-purpose programming language.
# Python's design philosophy emphasizes code readability
# with its notable use of significant indentation.

# %% [markdown]
# ### Case 8

# %%
str1 = """Python is a high-level and general-purpose programming language.
Python's design philosophy emphasizes code readability 
with its notable use of significant indentation.
"""

print(str1)
# Out:
# Python is a high-level and general-purpose programming language.
# Python's design philosophy emphasizes code readability
# with its notable use of significant indentation.

# %% [markdown]
# ### Case 9

# %%
a = 2.1111
b = 2.3333

print(a*b)
print(round(a*b, 2))
# Out:
# 4.92582963
# 4.93

# %% [markdown]
# ### Case 10

# %%
a = 5
b = 10
c = 20

print('{}+{}+{} = {}'.format(a, b, c, a + b + c))

print(str(a) + ' + ' + str(b) + ' + ' + str(c) + '  =  ' + 
str(a+b+c))
# Out:
# 5+10+20 = 35
# 5 + 10 + 20  =  35

# %% [markdown]
# ### Case 11

# %%
a = 2.1111
b = 2.3333

print('{}*{} = {:.2f}'.format(a, b, a*b))
# Out:
# 2.1111*2.3333 = 4.93

# %% [markdown]
# # Input

# %% [markdown]
# ### Case 1

# %%
username = input("Enter username: ")
print("Username is: " + username)
# Out:
# Enter username: NYC326
# Username is: NYC326

# %% [markdown]
# ### Quiz 2-1

# %%
pi = 3.14
rad = float(input("Radius: "))
area = pi*rad*rad
print("Area: %.1f" % area)
# Out:
# Radius: 10
# Area: 314.0

# %% [markdown]
# ### Quiz 2-2

# %%
eng = int(input("English : "))
math = int(input("Mathematics: "))
sci = int(input("Science: "))
print("Average score: %.1f" % float((eng+math+sci)/3))
# Out:
# English : 80
# Mathematics: 85
# Science: 90
# Average score: 85.0
